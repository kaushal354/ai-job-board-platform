# %%
print("hello")
print("hello","world")
print(23+25)
name = "kaushal"
age = 23
price = 25.99
print(name,price, age)
age2= age
print(age2)
print("my name is :",name)
print("my age is:",age)
print("the price is:",price)
print(type(name))
print(type(age))
print(type(price))
# Out:
# hello
# hello world
# 48
# kaushal 25.99 23
# 23
# my name is : kaushal
# my age is: 23
# the price is: 25.99
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a = None
print(a)
b = True
print(b)
print(type(a))
print(type(b))
# Out:
# None
# True
# <class 'NoneType'>
# <class 'bool'>

# %%
a = 2
a = 3
sum = a+b
print(sum)
# Out:
# 4

# %%
a,b = 2,3
txt = '@'
print(a*txt*b)
a,b = "2",3
txt = "@"
print((a+txt)*b)
a,b = 2,3
c = 4
print(a+b*c)
a,b = 10, 5.0
c = a*b
print(c)
a,b = 1,2
c = a/b
print(c)
a,b = 1.5,3
c = a//b
print(c,a/b)
# single comment
""" double comment"""
# Out:
# @@@@@@
# 2@2@2@
# 14
# 50.0
# 0.5
# 0.0 0.5
# ' double comment'

# %%
a,b = -5,2
c = a%b
print(c)
a,b = 5,-2
c = a%b
print(c)
# Out:
# 1
# -1

# %%
name = input("name:")
print(name)
age = int(input("age:"))
print(age)
price = float(input("price"))
print(price)
correct = bool(input("yes or no"))
print(correct)
# Out:
# yes
# 855
# 74.0
# True

# %%
print(1+2,2-4,3*8,2/8,3//5,5%2,2**3) #arthematic operator
# Out:
# 3 -2 24 0.25 0 1 8

# %%
print("kaushal" == "kaushal")#relational operator 
print("kaushal" != "janvii")
print(23>16)
print(16<52)
print(23>=24)
print(14<=16)
# Out:
# True
# True
# True
# True
# False
# True

# %%
name = 25 # assignment operator
name += 2
print(name)
name -= 2
print(name)
name *= 2
print(name)
name /= 2
print(name)
name %= 24
print(name)
name //= 5
print(name)
name **= 3
print(name)
# Out:
# 27
# 25
# 50
# 25.0
# 1.0
# 0.0
# 0.0

# %%
name = 5 # logical operator
age = 5
a = not(5>5)
print(a)
a = (2>3) and (3<2)
print(a)
b = (3>5) or (4<9)
print(b)
# Out:
# True
# False
# True

# %%
a = 'hello' #membership operator 
if 'e' in a:
    print(a)
if 'o' not in a:
    print(a)
# Out:
# hello

# %%
a = [1,2,3] #identity oprator
b = a
print(a is b)
x = [1,2,3]
y = [1,2,3]
print(x is not y)
# Out:
# True
# True

# %%
a = 16 & 13 # bitwise operator
print(a)
b = 16 | 13
print(b)
c = 16 ^ 13 
print(c)
d = 16 << 2
print(d)
e = 16 >> 2
print(e)
# Out:
# 0
# 29
# 29
# 64
# 4

# %%
#take 2 no & print thrir sum 
first_num = int(input("enter a 1st no"))
second_num = int(input("enter a 2nd no"))
sum = first_num + second_num
print(sum)
# Out:
# 48

# %%
#conditional statemnt
light = input("light:")
if light == "red":
    print("stop")
elif light == "yellow":
    print("wait")
elif light == "green":
    print("go")
else:
    print("light broken")
# Out:
# stop

# %%
# type conversion - automatically , type casting - manually
a , b = 1,2.0
sum = a+b
print(sum)
a,b = 1 ,"2"
sum = a+b
print(sum)
# Out:
# 3.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       4 print(sum)
#       5 a,b = 1 ,"2"
# ----> 6 sum = a+b
#       7 print(sum)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#typecasting
a,b = 1, "2"
b = int(b)
print(a+b)
# Out:
# 3

# %%
#string 
str1 = "hello" + "world"
print(str1)
print(len(str1))
str1=  """this is string"""
print(str1.rstrip())
str2 = "this is string"
str3 = 'this is string'
str1 = 'this\t is string'
print(str1)
str1 = "apna" + " " + "college"
print(str1)
str1 = "apna"
print(str1[1])
print(str1[0:len(str1)])
print(str1[-3:-1])
print(type(str1))
#string function 
str1 = "i am a coder"
print(str1.endswith("er"))
print(str1.capitalize())
print(str1.upper())
print(str1.lower())
print(str1.find("am"))
print(str1.count("a"))
print(str1.split(" "))
# Out:
# helloworld
# 10
# this is string
# this	 is string
# apna college
# p
# apna
# pn
# <class 'str'>
# True
# I am a coder
# I AM A CODER
# i am a coder
# 2
# 2
# ['i', 'am', 'a', 'coder']
